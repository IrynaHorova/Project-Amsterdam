# %%
import pandas as pd

# %%
data = pd.read_csv('../data/cleansed/cle_grants_employment_startups.csv')

# %%
data
# Out:
#    year  amount_requested_Culture  amount_requested_Sport  \
# 0  2016                3314060.67              3007982.24
# 1  2017               80231568.41              2651958.81
# 2  2018               81085866.57              2961184.52
# 3  2019               81679800.65              3629040.94
# 4  2020               92836634.09               552204.69
#
#    amount_granted_Culture  amount_granted_Sport  amount_given_Culture  \
# 0              2082725.84            2744956.71            2078632.28
# 1             78702906.59            1844397.50           77784362.59
# 2             78660651.22            2391249.07           77765617.52
# 3             80455808.80            2194447.34            2868955.36
# 4             90353610.81             410738.07             410045.21
#
#    amount_given_Sport  nr_one_off_Culture  nr_one_off_Sport  \
# 0          2675571.41               127.0              48.0
# 1          1542359.50               208.0              31.0
# 2          1635196.35               214.0              46.0
# 3           823125.81               185.0              29.0
# 4             3066.30                99.0               1.0
#
#    nr_periodic_Culture  nr_periodic_Sport  nr_subsidies_Culture  \
# 0                 22.0               20.0                 149.0
# 1                 66.0               14.0                 274.0
# 2                 61.0                0.0                 275.0
# 3                 27.0                0.0                 212.0
# 4                  1.0                0.0                 100.0
#
#    nr_subsidies_Sport  amount_requested_Total  amount_granted_Total  \
# 0                68.0              6322042.91            4827682.55
# 1                45.0             82883527.22           80547304.09
# 2                46.0             84047051.09           81051900.29
# 3                29.0             85308841.59           82650256.14
# 4                 1.0             93388838.78           90764348.88
#
#    amount_given_Total  nr_subsidies_Total  startups_in_sport_culture  \
# 0          4754203.69               217.0                     1178.0
# 1         79326722.09               319.0                     1188.0
# 2         79400813.87               321.0                     1129.0
# 3          3692081.17               241.0                     1116.0
# 4           413111.51               101.0                        NaN
#
#    employers_sports_culture  employees_sports_culture
# 0                     14590                     25443
# 1                     14957                     25949
# 2                     15517                     26820
# 3                     15514                     26939
# 4                     16286                     27672

# %%
grants_empl = data

# %%
grants_empl['average_grant_amount_total'] = grants_empl['amount_given_Total'] / grants_empl['nr_subsidies_Total']
grants_empl['average_grant_amount_Sport'] = grants_empl['amount_given_Sport'] / grants_empl['nr_subsidies_Sport']
grants_empl['average_grant_amount_Culture'] = grants_empl['amount_given_Culture'] / grants_empl['nr_subsidies_Culture']

# %%
grants_empl
# Out:
#    year  amount_requested_Culture  amount_requested_Sport  \
# 0  2016                3314060.67              3007982.24
# 1  2017               80231568.41              2651958.81
# 2  2018               81085866.57              2961184.52
# 3  2019               81679800.65              3629040.94
# 4  2020               92836634.09               552204.69
#
#    amount_granted_Culture  amount_granted_Sport  amount_given_Culture  \
# 0              2082725.84            2744956.71            2078632.28
# 1             78702906.59            1844397.50           77784362.59
# 2             78660651.22            2391249.07           77765617.52
# 3             80455808.80            2194447.34            2868955.36
# 4             90353610.81             410738.07             410045.21
#
#    amount_given_Sport  nr_one_off_Culture  nr_one_off_Sport  \
# 0          2675571.41               127.0              48.0
# 1          1542359.50               208.0              31.0
# 2          1635196.35               214.0              46.0
# 3           823125.81               185.0              29.0
# 4             3066.30                99.0               1.0
#
#    nr_periodic_Culture  ...  amount_requested_Total  amount_granted_Total  \
# 0                 22.0  ...              6322042.91            4827682.55
# 1                 66.0  ...             82883527.22           80547304.09
# 2                 61.0  ...             84047051.09           81051900.29
# 3                 27.0  ...             85308841.59           82650256.14
# 4                  1.0  ...             93388838.78           90764348.88
#
#    amount_given_Total  nr_subsidies_Total  startups_in_sport_culture  \
# 0          4754203.69               217.0                     1178.0
# 1         79326722.09               319.0                     1188.0
# 2         79400813.87               321.0                     1129.0
# 3          3692081.17               241.0                     1116.0
# 4           413111.51               101.0                        NaN
#
#    employers_sports_culture  employees_sports_culture  \
# 0                     14590                     25443
# 1                     14957                     25949
# 2                     15517                     26820
# 3                     15514                     26939
# 4                     16286                     27672
#
#    average_grant_amount_total  average_grant_amount_Sport  \
# 0                21908.772765                39346.638382
# 1               248673.110000                34274.655556
# 2               247354.560343                35547.746739
# 3                15319.838880                28383.648621
# 4                 4090.212970                 3066.300000
#
#    average_grant_amount_Culture
# 0                  13950.552215
# 1                 283884.535000
# 2                 282784.063709
# 3                  13532.808302
# 4                   4100.452100
#
# [5 rows x 23 columns]

# %%
grants_empl_percent_change = grants_empl.pct_change()
grants_empl_percent_change
# Out:
#        year  amount_requested_Culture  amount_requested_Sport  \
# 0       NaN                       NaN                     NaN
# 1  0.000496                 23.209445               -0.118360
# 2  0.000496                  0.010648                0.116603
# 3  0.000496                  0.007325                0.225537
# 4  0.000495                  0.136592               -0.847837
#
#    amount_granted_Culture  amount_granted_Sport  amount_given_Culture  \
# 0                     NaN                   NaN                   NaN
# 1               36.788414             -0.328078             36.420935
# 2               -0.000537              0.296493             -0.000241
# 3                0.022822             -0.082301             -0.963108
# 4                0.123022             -0.812828             -0.857075
#
#    amount_given_Sport  nr_one_off_Culture  nr_one_off_Sport  \
# 0                 NaN                 NaN               NaN
# 1           -0.423540            0.637795         -0.354167
# 2            0.060191            0.028846          0.483871
# 3           -0.496620           -0.135514         -0.369565
# 4           -0.996275           -0.464865         -0.965517
#
#    nr_periodic_Culture  ...  amount_requested_Total  amount_granted_Total  \
# 0                  NaN  ...                     NaN                   NaN
# 1             2.000000  ...               12.110244             15.684466
# 2            -0.075758  ...                0.014038              0.006265
# 3            -0.557377  ...                0.015013              0.019720
# 4            -0.962963  ...                0.094715              0.098174
#
#    amount_given_Total  nr_subsidies_Total  startups_in_sport_culture  \
# 0                 NaN                 NaN                        NaN
# 1           15.685596            0.470046                   0.008489
# 2            0.000934            0.006270                  -0.049663
# 3           -0.953501           -0.249221                  -0.011515
# 4           -0.888109           -0.580913                   0.000000
#
#    employers_sports_culture  employees_sports_culture  \
# 0                       NaN                       NaN
# 1                  0.025154                  0.019888
# 2                  0.037441                  0.033566
# 3                 -0.000193                  0.004437
# 4                  0.049762                  0.027210
#
#    average_grant_amount_total  average_grant_amount_Sport  \
# 0                         NaN                         NaN
# 1                   10.350390                   -0.128905
# 2                   -0.005302                    0.037144
# 3                   -0.938065                   -0.201535
# 4                   -0.733012                   -0.891969
#
#    average_grant_amount_Culture
# 0                           NaN
# 1                     19.349340
# 2                     -0.003876
# 3                     -0.952144
# 4                     -0.696999
#
# [5 rows x 23 columns]

# %%
grants_empl_percent_change['year'] = grants_empl['year']

# %%
grants_empl_percent_change
# Out:
#    year  amount_requested_Culture  amount_requested_Sport  \
# 0  2016                       NaN                     NaN
# 1  2017                 23.209445               -0.118360
# 2  2018                  0.010648                0.116603
# 3  2019                  0.007325                0.225537
# 4  2020                  0.136592               -0.847837
#
#    amount_granted_Culture  amount_granted_Sport  amount_given_Culture  \
# 0                     NaN                   NaN                   NaN
# 1               36.788414             -0.328078             36.420935
# 2               -0.000537              0.296493             -0.000241
# 3                0.022822             -0.082301             -0.963108
# 4                0.123022             -0.812828             -0.857075
#
#    amount_given_Sport  nr_one_off_Culture  nr_one_off_Sport  \
# 0                 NaN                 NaN               NaN
# 1           -0.423540            0.637795         -0.354167
# 2            0.060191            0.028846          0.483871
# 3           -0.496620           -0.135514         -0.369565
# 4           -0.996275           -0.464865         -0.965517
#
#    nr_periodic_Culture  ...  amount_requested_Total  amount_granted_Total  \
# 0                  NaN  ...                     NaN                   NaN
# 1             2.000000  ...               12.110244             15.684466
# 2            -0.075758  ...                0.014038              0.006265
# 3            -0.557377  ...                0.015013              0.019720
# 4            -0.962963  ...                0.094715              0.098174
#
#    amount_given_Total  nr_subsidies_Total  startups_in_sport_culture  \
# 0                 NaN                 NaN                        NaN
# 1           15.685596            0.470046                   0.008489
# 2            0.000934            0.006270                  -0.049663
# 3           -0.953501           -0.249221                  -0.011515
# 4           -0.888109           -0.580913                   0.000000
#
#    employers_sports_culture  employees_sports_culture  \
# 0                       NaN                       NaN
# 1                  0.025154                  0.019888
# 2                  0.037441                  0.033566
# 3                 -0.000193                  0.004437
# 4                  0.049762                  0.027210
#
#    average_grant_amount_total  average_grant_amount_Sport  \
# 0                         NaN                         NaN
# 1                   10.350390                   -0.128905
# 2                   -0.005302                    0.037144
# 3                   -0.938065                   -0.201535
# 4                   -0.733012                   -0.891969
#
#    average_grant_amount_Culture
# 0                           NaN
# 1                     19.349340
# 2                     -0.003876
# 3                     -0.952144
# 4                     -0.696999
#
# [5 rows x 23 columns]
