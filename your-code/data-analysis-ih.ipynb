# %%
import pandas as pd
import numpy as np
from scipy.stats import pearsonr

# %%
data = pd.read_csv('../data/cleansed/cle_grants_employment_startups.csv')

# %%
data_fd = pd.read_csv('../data/cleansed/Facilities_Diseases.csv')

# %%
data
# Out:
#    year  amount_requested_Culture  amount_requested_Sport  \
# 0  2016                3314060.67              3007982.24
# 1  2017               80231568.41              2651958.81
# 2  2018               81085866.57              2961184.52
# 3  2019               81679800.65              3629040.94
# 4  2020               92836634.09               552204.69
#
#    amount_granted_Culture  amount_granted_Sport  amount_given_Culture  \
# 0              2082725.84            2744956.71            2078632.28
# 1             78702906.59            1844397.50           77784362.59
# 2             78660651.22            2391249.07           77765617.52
# 3             80455808.80            2194447.34            2868955.36
# 4             90353610.81             410738.07             410045.21
#
#    amount_given_Sport  nr_one_off_Culture  nr_one_off_Sport  \
# 0          2675571.41               127.0              48.0
# 1          1542359.50               208.0              31.0
# 2          1635196.35               214.0              46.0
# 3           823125.81               185.0              29.0
# 4             3066.30                99.0               1.0
#
#    nr_periodic_Culture  ...  nr_subsidies_Sport  amount_requested_Total  \
# 0                 22.0  ...                68.0              6322042.91
# 1                 66.0  ...                45.0             82883527.22
# 2                 61.0  ...                46.0             84047051.09
# 3                 27.0  ...                29.0             85308841.59
# 4                  1.0  ...                 1.0             93388838.78
#
#    amount_granted_Total  amount_given_Total  nr_subsidies_Total  \
# 0            4827682.55          4754203.69               217.0
# 1           80547304.09         79326722.09               319.0
# 2           81051900.29         79400813.87               321.0
# 3           82650256.14          3692081.17               241.0
# 4           90764348.88           413111.51               101.0
#
#    startups_in_sport_culture  employers_sports_culture  \
# 0                     1178.0                     14590
# 1                     1188.0                     14957
# 2                     1129.0                     15517
# 3                     1116.0                     15514
# 4                        NaN                     16286
#
#    pct_employers_sports_cultures  employees_sports_culture  \
# 0                       0.132861                     25443
# 1                       0.131084                     25949
# 2                       0.129078                     26820
# 3                       0.127975                     26939
# 4                       0.124784                     27672
#
#    pct_employees_sports_culture
# 0                      0.049894
# 1                      0.049240
# 2                      0.049187
# 3                      0.048346
# 4                      0.047359
#
# [5 rows x 22 columns]

# %%
data_fd
# Out:
#    Unnamed: 0  One or more times a week  One or more times a month  \
# 0        2016                       nan                        nan
# 1        2017                     66.00                      74.00
# 2        2018                     70.00                      76.00
# 3        2019                     72.00                      78.00
# 4        2020                     62.00                      68.00
#
#    Fitness (individually)  Sprinting/Jogging  Hiking  Swimming  \
# 0                     nan                nan     nan       nan
# 1                   26.00              13.00   12.00     11.00
# 2                   28.00              15.00   12.00     11.00
# 3                   29.00              17.00   13.00     11.00
# 4                   26.00              24.00   21.00      0.00
#
#    Fitness in group  Yoga  Cycling  Football  Dancing  \
# 0               nan   nan      nan       nan      nan
# 1              9.00  9.00     4.00      5.00     5.00
# 2             10.00  9.00     5.00      8.00     6.00
# 3             11.00  9.00     8.00      8.00     5.00
# 4              0.00 10.00    14.00      3.00     2.00
#
#    Heart- & Artery Disease  Total diseases  Heart- & Artery Disease(%)  \
# 0                 1,294.00        5,517.00                       23.50
# 1                 1,206.00        5,169.00                       23.30
# 2                 1,175.00        5,374.00                       21.90
# 3                 1,155.00        5,248.00                       22.00
# 4                      nan             nan                         nan
#
#    Total(%)  Total facilities sum
# 0    100.00                   832
# 1    100.00                   825
# 2    100.00                   811
# 3    100.00                   811
# 4       nan                   803

# %%
grants_empl = data

# %%
grants_empl['average_grant_amount_total'] = grants_empl['amount_given_Total'] / grants_empl['nr_subsidies_Total']
grants_empl['average_grant_amount_Sport'] = grants_empl['amount_given_Sport'] / grants_empl['nr_subsidies_Sport']
grants_empl['average_grant_amount_Culture'] = grants_empl['amount_given_Culture'] / grants_empl['nr_subsidies_Culture']

# %%
selected_grants_empl = grants_empl[['year', 
                                    'amount_given_Total',  
                                    'nr_subsidies_Total',
                                    'average_grant_amount_total',
                                    'startups_in_sport_culture',
                                    'employers_sports_culture',
                                    'pct_employers_sports_cultures',
                                    'employees_sports_culture',
                                    'pct_employees_sports_culture'
                                   ]]\
.set_index('year')

selected_grants_empl.transpose()
# Out:
# year                                  2016          2017          2018  \
# amount_given_Total            4,754,203.69 79,326,722.09 79,400,813.87
# nr_subsidies_Total                  217.00        319.00        321.00
# average_grant_amount_total       21,908.77    248,673.11    247,354.56
# startups_in_sport_culture         1,178.00      1,188.00      1,129.00
# employers_sports_culture         14,590.00     14,957.00     15,517.00
# pct_employers_sports_cultures         0.13          0.13          0.13
# employees_sports_culture         25,443.00     25,949.00     26,820.00
# pct_employees_sports_culture          0.05          0.05          0.05
#
# year                                  2019       2020
# amount_given_Total            3,692,081.17 413,111.51
# nr_subsidies_Total                  241.00     101.00
# average_grant_amount_total       15,319.84   4,090.21
# startups_in_sport_culture         1,116.00        nan
# employers_sports_culture         15,514.00  16,286.00
# pct_employers_sports_cultures         0.13       0.12
# employees_sports_culture         26,939.00  27,672.00
# pct_employees_sports_culture          0.05       0.05

# %%
selected_grants_empl.reset_index()['year']
# Out:
# 0    2016
# 1    2017
# 2    2018
# 3    2019
# 4    2020
# Name: year, dtype: int64

# %% [markdown]
# # percentage growth

# %%
grants_empl_percent_change = selected_grants_empl.pct_change()
grants_empl_percent_change['year'] = selected_grants_empl.reset_index()['year']
pd.options.display.float_format = '{:,.2f}'.format
grants_empl_percent_change.transpose()
# Out:
# year                           2016  2017  2018  2019  2020
# amount_given_Total              nan 15.69  0.00 -0.95 -0.89
# nr_subsidies_Total              nan  0.47  0.01 -0.25 -0.58
# average_grant_amount_total      nan 10.35 -0.01 -0.94 -0.73
# startups_in_sport_culture       nan  0.01 -0.05 -0.01  0.00
# employers_sports_culture        nan  0.03  0.04 -0.00  0.05
# pct_employers_sports_cultures   nan -0.01 -0.02 -0.01 -0.02
# employees_sports_culture        nan  0.02  0.03  0.00  0.03
# pct_employees_sports_culture    nan -0.01 -0.00 -0.02 -0.02
# year                            nan   nan   nan   nan   nan

# %%
selected_grants_empl.transpose()
# Out:
# year                                  2016          2017          2018  \
# amount_given_Total            4,754,203.69 79,326,722.09 79,400,813.87
# nr_subsidies_Total                  217.00        319.00        321.00
# average_grant_amount_total       21,908.77    248,673.11    247,354.56
# startups_in_sport_culture         1,178.00      1,188.00      1,129.00
# employers_sports_culture         14,590.00     14,957.00     15,517.00
# pct_employers_sports_cultures         0.13          0.13          0.13
# employees_sports_culture         25,443.00     25,949.00     26,820.00
# pct_employees_sports_culture          0.05          0.05          0.05
#
# year                                  2019       2020
# amount_given_Total            3,692,081.17 413,111.51
# nr_subsidies_Total                  241.00     101.00
# average_grant_amount_total       15,319.84   4,090.21
# startups_in_sport_culture         1,116.00        nan
# employers_sports_culture         15,514.00  16,286.00
# pct_employers_sports_cultures         0.13       0.12
# employees_sports_culture         26,939.00  27,672.00
# pct_employees_sports_culture          0.05       0.05

# %% [markdown]
# # correlations

# %%
df1 = selected_grants_empl.loc[:, selected_grants_empl.columns != 'startups_in_sport_culture']
df2 = selected_grants_empl.loc[:, selected_grants_empl.columns != 'startups_in_sport_culture']

coeffmat = np.zeros((df1.shape[1], df2.shape[1]))
pvalmat = np.zeros((df1.shape[1], df2.shape[1]))

for i in range(df1.shape[1]):    
    for j in range(df2.shape[1]):        
        corrtest = pearsonr(df1[df1.columns[i]], df2[df2.columns[j]])  
        coeffmat[i,j] = corrtest[0]
        pvalmat[i,j] = corrtest[1]

# dfcoeff = pd.DataFrame(coeffmat, columns=df2.columns, index=df1.columns)
# dfcoeff
# #           Col1      Col2      Col3      Col4      Col5
# # Col1 -0.791083  0.459101 -0.488463 -0.289265  0.494897
# # Col2  0.059446 -0.395072  0.310900  0.297532  0.201669
# # Col3 -0.062592  0.391469 -0.450600 -0.136554  0.299579
# # Col4 -0.470203  0.797971 -0.193561 -0.338896 -0.244132
# # Col5 -0.057848 -0.037053  0.042798  0.176966 -0.157344

dfpvals = pd.DataFrame(pvalmat, columns=df2.columns, index=df1.columns)
print('correlation significance')
dfpvals
#           Col1      Col2      Col3      Col4      Col5
# Col1  0.006421  0.181967  0.152007  0.417574  0.145871
# Col2  0.870421  0.258506  0.381919  0.403770  0.576357
# Col3  0.863615  0.263268  0.191245  0.706796  0.400385
# Col4  0.170260  0.005666  0.592096  0.338101  0.496668
# Col5  0.873881  0.919058  0.906551  0.624783  0.664206
# Out:
# correlation significance
#                                amount_given_Total  nr_subsidies_Total  \
# amount_given_Total                           0.00                0.08
# nr_subsidies_Total                           0.08                0.00
# average_grant_amount_total                   0.00                0.08
# employers_sports_culture                     0.72                0.33
# pct_employers_sports_cultures                0.62                0.29
# employees_sports_culture                     0.72                0.40
# pct_employees_sports_culture                 0.49                0.21
#
#                                average_grant_amount_total  \
# amount_given_Total                                   0.00
# nr_subsidies_Total                                   0.08
# average_grant_amount_total                           0.00
# employers_sports_culture                             0.70
# pct_employers_sports_cultures                        0.60
# employees_sports_culture                             0.71
# pct_employees_sports_culture                         0.48
#
#                                employers_sports_culture  \
# amount_given_Total                                 0.72
# nr_subsidies_Total                                 0.33
# average_grant_amount_total                         0.70
# employers_sports_culture                           0.00
# pct_employers_sports_cultures                      0.00
# employees_sports_culture                           0.00
# pct_employees_sports_culture                       0.02
#
#                                pct_employers_sports_cultures  \
# amount_given_Total                                      0.62
# nr_subsidies_Total                                      0.29
# average_grant_amount_total                              0.60
# employers_sports_culture                                0.00
# pct_employers_sports_cultures                           0.00
# employees_sports_culture                                0.00
# pct_employees_sports_culture                            0.01
#
#                                employees_sports_culture  \
# amount_given_Total                                 0.72
# nr_subsidies_Total                                 0.40
# average_grant_amount_total                         0.71
# employers_sports_culture                           0.00
# pct_employers_sports_cultures                      0.00
# employees_sports_culture                           0.00
# pct_employees_sports_culture                       0.02
#
#                                pct_employees_sports_culture
# amount_given_Total                                     0.49
# nr_subsidies_Total                                     0.21
# average_grant_amount_total                             0.48
# employers_sports_culture                               0.02
# pct_employers_sports_cultures                          0.01
# employees_sports_culture                               0.02
# pct_employees_sports_culture                           0.00

# %%
print('correlation matrix')
selected_grants_empl.corr()
# Out:
# correlation matrix
#                                amount_given_Total  nr_subsidies_Total  \
# amount_given_Total                           1.00                0.83
# nr_subsidies_Total                           0.83                1.00
# average_grant_amount_total                   1.00                0.83
# startups_in_sport_culture                    0.19                0.04
# employers_sports_culture                    -0.23               -0.56
# pct_employers_sports_cultures                0.31                0.60
# employees_sports_culture                    -0.22               -0.49
# pct_employees_sports_culture                 0.41                0.68
#
#                                average_grant_amount_total  \
# amount_given_Total                                   1.00
# nr_subsidies_Total                                   0.83
# average_grant_amount_total                           1.00
# startups_in_sport_culture                            0.20
# employers_sports_culture                            -0.24
# pct_employers_sports_cultures                        0.32
# employees_sports_culture                            -0.23
# pct_employees_sports_culture                         0.43
#
#                                startups_in_sport_culture  \
# amount_given_Total                                  0.19
# nr_subsidies_Total                                  0.04
# average_grant_amount_total                          0.20
# startups_in_sport_culture                           1.00
# employers_sports_culture                           -0.89
# pct_employers_sports_cultures                       0.90
# employees_sports_culture                           -0.91
# pct_employees_sports_culture                        0.75
#
#                                employers_sports_culture  \
# amount_given_Total                                -0.23
# nr_subsidies_Total                                -0.56
# average_grant_amount_total                        -0.24
# startups_in_sport_culture                         -0.89
# employers_sports_culture                           1.00
# pct_employers_sports_cultures                     -0.99
# employees_sports_culture                           0.99
# pct_employees_sports_culture                      -0.94
#
#                                pct_employers_sports_cultures  \
# amount_given_Total                                      0.31
# nr_subsidies_Total                                      0.60
# average_grant_amount_total                              0.32
# startups_in_sport_culture                               0.90
# employers_sports_culture                               -0.99
# pct_employers_sports_cultures                           1.00
# employees_sports_culture                               -0.99
# pct_employees_sports_culture                            0.97
#
#                                employees_sports_culture  \
# amount_given_Total                                -0.22
# nr_subsidies_Total                                -0.49
# average_grant_amount_total                        -0.23
# startups_in_sport_culture                         -0.91
# employers_sports_culture                           0.99
# pct_employers_sports_cultures                     -0.99
# employees_sports_culture                           1.00
# pct_employees_sports_culture                      -0.92
#
#                                pct_employees_sports_culture
# amount_given_Total                                     0.41
# nr_subsidies_Total                                     0.68
# average_grant_amount_total                             0.43
# startups_in_sport_culture                              0.75
# employers_sports_culture                              -0.94
# pct_employers_sports_cultures                          0.97
# employees_sports_culture                              -0.92
# pct_employees_sports_culture                           1.00

# %%
#startups in sport/culture

df1 = selected_grants_empl.loc[:, selected_grants_empl.columns != 'startups_in_sport_culture']
df2 = selected_grants_empl.loc[:, selected_grants_empl.columns != 'startups_in_sport_culture']

coeffmat = np.zeros((df1.shape[1], df2.shape[1]))
pvalmat = np.zeros((df1.shape[1], df2.shape[1]))

for i in range(df1.shape[1]):    
    for j in range(df2.shape[1]):        
        corrtest = pearsonr(df1[df1.columns[i]], df2[df2.columns[j]])  
        coeffmat[i,j] = corrtest[0]
        pvalmat[i,j] = corrtest[1]

# dfcoeff = pd.DataFrame(coeffmat, columns=df2.columns, index=df1.columns)
# dfcoeff
# #           Col1      Col2      Col3      Col4      Col5
# # Col1 -0.791083  0.459101 -0.488463 -0.289265  0.494897
# # Col2  0.059446 -0.395072  0.310900  0.297532  0.201669
# # Col3 -0.062592  0.391469 -0.450600 -0.136554  0.299579
# # Col4 -0.470203  0.797971 -0.193561 -0.338896 -0.244132
# # Col5 -0.057848 -0.037053  0.042798  0.176966 -0.157344

dfpvals = pd.DataFrame(pvalmat, columns=df2.columns, index=df1.columns)
print('correlation significance')
dfpvals
#           Col1      Col2      Col3      Col4      Col5
# Col1  0.006421  0.181967  0.152007  0.417574  0.145871
# Col2  0.870421  0.258506  0.381919  0.403770  0.576357
# Col3  0.863615  0.263268  0.191245  0.706796  0.400385
# Col4  0.170260  0.005666  0.592096  0.338101  0.496668
# Col5  0.873881  0.919058  0.906551  0.624783  0.664206
